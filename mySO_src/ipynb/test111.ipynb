# %%
import xarray as xr

# %%
A=xr.open_dataset('J:/tmp_proc/Models/myGECCO_195501_201812_ztshuv.nc')

# %%
B=A.u.loc[dict(depth=slice(0,10),lon=slice(160,220),lat=slice(-80,-40))].mean(dim=['time','depth'])

# %%
B=B.where(B<100000)
B=B.where(B>-100000)

# %%
B.plot()

# %%
import xarray as xr
ECCO=xr.open_dataset( 'D:/ECCO/tmp/VEL/OCEAN_VELOCITY_mon_mean_2017-02_ECCO_V4r4_latlon_0p50deg.nc' )['EVEL']\
    .loc[dict(Z=slice(0,-6),longitude=slice(160,220),latitude=slice(-80,-50))]#.mean(dim=['time','depth'])
# Out:
# c:\Users\shjo\miniconda3\envs\nemo_env\lib\site-packages\xarray\backends\plugins.py:80: RuntimeWarning: Engine 'cfgrib' loading failed:
# Cannot find the ecCodes library
#   warnings.warn(f"Engine {name!r} loading failed:\n{ex}", RuntimeWarning)

# %%
ECCO.squeeze()
# Out:
# <xarray.DataArray 'EVEL' (latitude: 60, longitude: 40)>
# [2400 values with dtype=float32]
# Coordinates:
#     time       datetime64[ns] 2017-02-15
#     Z          float32 -5.0
#   * latitude   (latitude) float32 -79.75 -79.25 -78.75 ... -51.25 -50.75 -50.25
#   * longitude  (longitude) float32 160.2 160.8 161.2 161.8 ... 178.8 179.2 179.8
# Attributes:
#     coverage_content_type:  modelResult
#     long_name:              Zonal (east-west) velocity
#     standard_name:          eastward_sea_water_velocity
#     units:                  m s-1
#     comment:                Zonal (east-west) component of ocean velocity. No...
#     valid_min:              -1.293381929397583
#     valid_max:              1.6734176874160767

# %%
import sys
sys.path.append('C:/Users/shjo/Bridge/JNUpack/mySO_src/libs/')
import matplotlib as mpl
from myPlot import  figmaster,myClrbr
from myPlot import  figmaster,myClrbr, dta_colr
import numpy as np
import matplotlib.pyplot as plt
DATA=ECCO.squeeze().values
mySetting={
    'figsize': '',
    'mylabel': '',
    'Label_size':18,
    'title_loc':'right',
    'fontParams':'Arial',
    'wpth':'J:/tmp_proc/Models/GECCO_1980/'}

lonR_m,latR_m=np.meshgrid(ECCO.longitude.values,ECCO.latitude.values)


F=figmaster(mySetting)
F.myCrtpy_cyl_pcolor(latR_m,lonR_m,DATA,plt.get_cmap('jet',15))
# Out:
# c:\Users\shjo\miniconda3\envs\nemo_env\lib\site-packages\cartopy\mpl\gridliner.py:451: UserWarning: The .xlabels_top attribute is deprecated. Please use .top_labels to toggle visibility instead.
#   warnings.warn('The .xlabels_top attribute is deprecated. Please '
# c:\Users\shjo\miniconda3\envs\nemo_env\lib\site-packages\cartopy\mpl\gridliner.py:487: UserWarning: The .ylabels_right attribute is deprecated. Please use .right_labels to toggle visibility instead.
#   warnings.warn('The .ylabels_right attribute is deprecated. Please '
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# c:\Users\shjo\Bridge\JNUpack\mySO_src\ipynb\test111.ipynb Cell 8 line 2
#      <a href='vscode-notebook-cell:/c%3A/Users/shjo/Bridge/JNUpack/mySO_src/ipynb/test111.ipynb#X10sZmlsZQ%3D%3D?line=16'>17</a> lonR_m,latR_m=np.meshgrid(ECCO.longitude.values,ECCO.latitude.values)
# ...

# %%
DATA=ECCO.squeeze().values

# %%
lonR_m.shape
# Out:
# (20, 40)

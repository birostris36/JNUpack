# %%
import xarray as xr

# %%
A=xr.open_dataset('E:/_data/MDLS_OBS_OHC/myISHII_198001_201912_tsh.nc')
# Out:
# c:\Users\shjo\miniconda3\envs\nemo_env\lib\site-packages\xarray\backends\plugins.py:80: RuntimeWarning: Engine 'cfgrib' loading failed:
# Cannot find the ecCodes library
#   warnings.warn(f"Engine {name!r} loading failed:\n{ex}", RuntimeWarning)

# %%
A.temp.loc[dict(depth=slice(0,700))][479]
# Out:
# <xarray.DataArray 'temp' (depth: 16, lat: 180, lon: 360)>
# [1036800 values with dtype=float64]
# Coordinates:
#   * lat      (lat) float32 -89.5 -88.5 -87.5 -86.5 -85.5 ... 86.5 87.5 88.5 89.5
#   * lon      (lon) float32 0.5 1.5 2.5 3.5 4.5 ... 355.5 356.5 357.5 358.5 359.5
#   * depth    (depth) float32 0.0 10.0 20.0 30.0 50.0 ... 400.0 500.0 600.0 700.0
#     time     datetime64[ns] 2019-12-15
# Attributes:
#     units:        degree_C
#     long_name:    Ishii (JMA) temp
#     coordinates:  time, depth, lat, lon

# %%
A.temp.time
# Out:
# <xarray.DataArray 'time' (time: 480)>
# array(['1980-01-15T00:00:00.000000000', '1980-02-15T00:00:00.000000000',
#        '1980-03-15T00:00:00.000000000', ..., '2019-10-15T00:00:00.000000000',
#        '2019-11-15T00:00:00.000000000', '2019-12-15T00:00:00.000000000'],
#       dtype='datetime64[ns]')
# Coordinates:
#   * time     (time) datetime64[ns] 1980-01-15 1980-02-15 ... 2019-12-15
# Attributes:
#     field:    time, scalar, series

# %%
try:
    A['dsaf']
except:
    print('BB')
# Out:
# BB

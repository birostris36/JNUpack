# %%
from netCDF4 import MFDataset,Dataset,num2date,date2num
import statsmodels.api as sm
from scipy.stats import  linregress
import numpy as np
import datetime as dt
import xarray as xr
import os

npth='J:/Reanalysis/myHadlSST_198001_202312_sst.nc'

sst=xr.open_dataset(npth).sst.loc[dict(lat=slice(-80,-60),time=slice('2005-01','2022-12'))]
sst=sst.where(sst<1000)
sst=sst.mean(dim=['lat','lon'])

# %%
model = sm.OLS(sst.values,np.arange(len(sst)))
result = model.fit()
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                      y   R-squared (uncentered):                   0.374
# Model:                            OLS   Adj. R-squared (uncentered):              0.371
# Method:                 Least Squares   F-statistic:                              128.4
# Date:                Fri, 22 Sep 2023   Prob (F-statistic):                    1.20e-23
# Time:                        20:21:37   Log-Likelihood:                         -243.83
# No. Observations:                 216   AIC:                                      489.7
# Df Residuals:                     215   BIC:                                      493.0
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1            -0.0047      0.000    -11.333      0.000      -0.005      -0.004
# ==============================================================================
# Omnibus:                       26.070   Durbin-Watson:                   0.310
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               16.019
# Skew:                           0.526   Prob(JB):                     0.000332
# Kurtosis:                       2.179   Cond. No.                         1.00
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
m, b, r_value, p_value, std_err = linregress(np.arange(len(sst)), sst.values)

# %%
model = sm.OLS(sst.values,np.arange(len(sst))).fit()
std_err = np.sqrt(np.sum(model.resid_pearson ** 2) / (len(y) - len(X.columns)))
print(f'Standard Error of the Regression: {std_err:.2f}')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\shjo\Bridge\JNUpack\SO\Trend\samples.ipynb Cell 4 line 2
#       <a href='vscode-notebook-cell:/c%3A/Users/shjo/Bridge/JNUpack/SO/Trend/samples.ipynb#W3sZmlsZQ%3D%3D?line=0'>1</a> model = sm.OLS(sst.values,np.arange(len(sst))).fit()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/shjo/Bridge/JNUpack/SO/Trend/samples.ipynb#W3sZmlsZQ%3D%3D?line=1'>2</a> std_err = np.sqrt(np.sum(model.resid_pearson ** 2) / (len(y) - len(X.columns)))
#       <a href='vscode-notebook-cell:/c%3A/Users/shjo/Bridge/JNUpack/SO/Trend/samples.ipynb#W3sZmlsZQ%3D%3D?line=2'>3</a> print(f'Standard Error of the Regression: {std_err:.2f}')
#
# NameError: name 'y' is not defined

# %%
np.sqrt(np.sum(model.resid_pearson ** 2) )
# Out:
# 22.781571499789038

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.arange(len(sst))
y = sst.values
n = x.size

# calculate interval manually using the formula
a, b = np.polyfit(x, y, deg=1)
y_est = a * x + b
y_err = (y-y_est).std() * np.sqrt(1/n + (x - x.mean())**2 / np.sum((x - x.mean())**2))
print(a)
print(b)
# Out:
# -0.0012608531135374346
# -0.4873594169574853

# %%
import seaborn as sns
fig, ax = plt.subplots()

# plot manually calculated interval (std interval) --- the blue one
ax.plot(x, y_est, '-')
ax.fill_between(x, y_est - y_err, y_est + y_err, alpha=0.2,color='r')

# plot seaborn calculated interval (std interval, i.e. when ci=68.27) --- the orange one
sns.regplot(x=x, y=y, color='grey')

plt.plot(x,y, color='grey')

plt.show()

# %%
slope, intercept, r_value, p_value, std_err = linregress(np.arange(len(sst)), sst.values)
print(m)
print(b)
print(r_value)
print(p_value)
print(std_err)
print(a)
# Out:
# -0.0012608531135374329
# -0.4873594169574855
# -0.11049985287615363
# 0.10532906006597703
# 0.000775225720897319
# -0.0012608531135374346

# %%
sst=xr.open_dataset(npth).sst.loc[dict(lat=slice(-80,-30),time=slice('2005-01','2022-12'))]
sst=sst.where(sst<1000)

# %%
NC=sst.assign_coords({'TT':('time',range(len(sst.time)))})
NC=NC.swap_dims({"time":"TT"})
NC_s=NC.polyfit(dim='TT',deg=1,skipna=False)
fit = xr.polyval(NC.TT, NC_s.polyfit_coefficients)
Coef=NC_s.polyfit_coefficients[0]
Coef_var=Coef.values*12 # (m/year)
data_dt=NC-fit
data_dt=data_dt.swap_dims({"TT":"time"})

# %%
plt.pcolor(Coef.values,vmin=-0.002,vmax=0.002,cmap=plt.get_cmap('bwr'))
plt.colorbar()
print(np.nanmean(Coef.values))
# Out:
# -0.0002819459298114854

# %%
plt.pcolor(tmp,vmin=-0.002,vmax=0.002,cmap=plt.get_cmap('bwr'))
plt.colorbar()

print(np.nanmean(tmp))
# Out:
# 0.0002426415158108955

# %%
# calculate interval manually using the formula
my=sst.values
T,A,O=my.shape
y=np.arange(T)
tmp=np.zeros([A,O])
for i in range(A):
    for j in range(O):
        if np.mean(my[:,i,j])!=np.mean(my[:,i,j]):
            tmp[i,j]=np.nan
        else:
            a,_=np.polyfit(y,my[:,i,j], deg=1)
            tmp[i,j]=a

# %%
y
# Out:
# array([[[        nan,         nan,         nan, ...,         nan,
#                  nan,         nan],
#         [        nan,         nan,         nan, ...,         nan,
#                  nan,         nan],
#         [        nan,         nan,         nan, ...,         nan,
#                  nan,         nan],
#         ...,
#         [21.57028198, 21.52470779, 21.62590027, ..., 22.25699043,
#          22.01142883, 21.77522278],
#         [21.99029922, 21.92670059, 22.01374054, ..., 22.89670563,
#          22.51155281, 22.2048893 ],
#         [22.44848633, 22.36904526, 22.36247253, ..., 23.49919319,
#          22.95162201, 22.59902573]],
#
#        [[        nan,         nan,         nan, ...,         nan,
#                  nan,         nan],
#         [        nan,         nan,         nan, ...,         nan,
#                  nan,         nan],
#         [        nan,         nan,         nan, ...,         nan,
#                  nan,         nan],
#         ...,
#         [22.40676308, 22.27745438, 22.19477081, ..., 22.98023605,
#          22.789505  , 22.58951187],
#         [22.8067894 , 22.64536858, 22.51829338, ..., 23.41765594,
#          23.20655632, 22.99547195],
#         [23.12504196, 22.92289352, 22.71785164, ..., 23.6747036 ,
#          23.48926926, 23.30306244]],
#
#        [[        nan,         nan,         nan, ...,         nan,
#                  nan,         nan],
#         [        nan,         nan,         nan, ...,         nan,
#                  nan,         nan],
#         [        nan,         nan,         nan, ...,         nan,
#                  nan,         nan],
#         ...,
#         [22.33960724, 22.2342701 , 22.16086578, ..., 22.70165634,
#          22.59196472, 22.47026062],
#         [22.67948151, 22.51320267, 22.37863922, ..., 23.1654892 ,
#          23.0178566 , 22.85972595],
#         [22.98363495, 22.76464653, 22.5334568 , ..., 23.49323273,
#          23.32930756, 23.16594696]],
#
#        ...,
#
#        [[        nan,         nan,         nan, ...,         nan,
#                  nan,         nan],
#         [        nan,         nan,         nan, ...,         nan,
#                  nan,         nan],
#         [        nan,         nan,         nan, ...,         nan,
#                  nan,         nan],
#         ...,
#         [22.02770615, 21.93911743, 21.84010315, ..., 22.23032951,
#          22.18907166, 22.11269379],
#         [22.41397476, 22.26792908, 22.11440659, ..., 22.75678444,
#          22.66719818, 22.54546738],
#         [22.73360062, 22.55668831, 22.40425873, ..., 23.27506638,
#          23.09723663, 22.91375923]],
#
#        [[        nan,         nan,         nan, ...,         nan,
#                  nan,         nan],
#         [        nan,         nan,         nan, ...,         nan,
#                  nan,         nan],
#         [        nan,         nan,         nan, ...,         nan,
#                  nan,         nan],
#         ...,
#         [21.65866661, 21.56171227, 21.46145058, ..., 21.96179581,
#          21.84775925, 21.74569702],
#         [22.12198257, 21.96564865, 21.7859726 , ..., 22.36362267,
#          22.31389809, 22.23722458],
#         [22.57543945, 22.3934288 , 22.17812538, ..., 22.6391449 ,
#          22.71440697, 22.69967651]],
#
#        [[        nan,         nan,         nan, ...,         nan,
#                  nan,         nan],
#         [        nan,         nan,         nan, ...,         nan,
#                  nan,         nan],
#         [        nan,         nan,         nan, ...,         nan,
#                  nan,         nan],
#         ...,
#         [20.83505249, 20.74597359, 20.70737648, ..., 21.05223083,
#          20.9938736 , 20.92811966],
#         [21.27605057, 21.16226006, 21.09838486, ..., 21.49328995,
#          21.44833755, 21.38408279],
#         [21.64120674, 21.51322937, 21.44637108, ..., 21.92016792,
#          21.86233521, 21.77845764]]])

# %%
tmp
# Out:
# array([[       nan,        nan,        nan, ...,        nan,        nan,
#                nan],
#        [       nan,        nan,        nan, ...,        nan,        nan,
#                nan],
#        [       nan,        nan,        nan, ...,        nan,        nan,
#                nan],
#        ...,
#        [1.8764166 , 2.20991285, 2.44040209, ..., 0.95668755, 1.13196315,
#         1.43666863],
#        [1.90659191, 2.24951744, 2.49656118, ..., 0.79918793, 1.10506916,
#         1.47140704],
#        [2.07255839, 2.3136338 , 2.44239474, ..., 1.10869817, 1.40690598,
#         1.72533125]])

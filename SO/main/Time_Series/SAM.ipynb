# %%
import pandas as pd

npth='C:/Users/shjo/OneDrive/mySO/mySignals/Ori/Ind_txt_SAM_1957_2020.txt'

# %%
import matplotlib.pyplot as plt
import pickle

SAM_=pd.read_csv(npth,delimiter=',',header=None)
t_index=pd.date_range(start='1957-01',freq='1MS',periods=768)

SAM_index=pd.DataFrame({'SAM_index':SAM_[2].values},index=t_index)

with open('C:/Users/shjo/OneDrive/mySO/mySignals/'+'SAM_index.pickle', 'wb') as f:
    pickle.dump(SAM_index, f, pickle.HIGHEST_PROTOCOL)

# %%
SAM_index['1980-01':].rolling(12,center=True).mean().plot()
# Out:
# <Axes: >

# %%
SAM_index['1993-01':].rolling(12,center=True).mean().plot()
# Out:
# <Axes: >
